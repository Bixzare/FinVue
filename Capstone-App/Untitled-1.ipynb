# %%
import pandas as pd
import numpy as np

# %%
df1
# Out:
#        age     workclass     education      marital-status         occupation  \
# 0       25       Private          11th       Never-married  Machine-op-inspct
# 1       38       Private       HS-grad  Married-civ-spouse    Farming-fishing
# 2       28     Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 3       44       Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 4       34       Private          10th       Never-married      Other-service
# ...    ...           ...           ...                 ...                ...
# 45170   27       Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 45171   40       Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 45172   58       Private       HS-grad             Widowed       Adm-clerical
# 45173   22       Private       HS-grad       Never-married       Adm-clerical
# 45174   52  Self-emp-inc       HS-grad  Married-civ-spouse    Exec-managerial
#
# ...

# %%
data = pd.read_csv("datasets/Credit Score/cred_score_cleaned.csv")
df = data.sample(n = 10000)

# %%
df['Credit_Score'].unique()
# Out:
# array([1, 2, 0], dtype=int64)

# %%
print(df.columns)
# Out:
# Index(['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Monthly_Balance', 'Credit_Score',
#        'Credit-Builder Loan', 'Personal Loan', 'Debt Consolidation Loan',
#        'Student Loan', 'Payday Loan', 'Mortgage Loan', 'Auto Loan',
#        'Home Equity Loan', 'Month_August', 'Month_February', 'Month_January',
#        'Month_July', 'Month_June', 'Month_March', 'Month_May',
#        'Occupation_Architect', 'Occupation_Developer', 'Occupation_Doctor',
#        'Occupation_Engineer', 'Occupation_Entrepreneur',
#        'Occupation_Journalist', 'Occupation_Lawyer', 'Occupation_Manager',
# ...

# %%
columns = df.columns.tolist()

# %%
columns
# Out:
# ['Age',
#  'Annual_Income',
#  'Monthly_Inhand_Salary',
#  'Num_Bank_Accounts',
#  'Num_Credit_Card',
#  'Interest_Rate',
#  'Num_of_Loan',
#  'Delay_from_due_date',
#  'Num_of_Delayed_Payment',
#  'Changed_Credit_Limit',
#  'Num_Credit_Inquiries',
#  'Credit_Mix',
#  'Outstanding_Debt',
#  'Credit_Utilization_Ratio',
#  'Credit_History_Age',
#  'Total_EMI_per_month',
#  'Amount_invested_monthly',
#  'Monthly_Balance',
#  'Credit_Score',
#  'Credit-Builder Loan',
#  'Personal Loan',
#  'Debt Consolidation Loan',
#  'Student Loan',
#  'Payday Loan',
#  'Mortgage Loan',
#  'Auto Loan',
#  'Home Equity Loan',
#  'Month_August',
#  'Month_February',
#  'Month_January',
#  'Month_July',
#  'Month_June',
#  'Month_March',
#  'Month_May',
#  'Occupation_Architect',
#  'Occupation_Developer',
#  'Occupation_Doctor',
#  'Occupation_Engineer',
#  'Occupation_Entrepreneur',
#  'Occupation_Journalist',
#  'Occupation_Lawyer',
#  'Occupation_Manager',
#  'Occupation_Mechanic',
# ...

# %%
len(columns)
# Out:
# 54

# %%
df1 = pd.read_csv('datasets/Credit Score/cred_score_cleaned.csv')

# %%
df1.columns
# Out:
# Index(['Month', 'Age', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score', 'Personal Loan', 'Credit-Builder Loan',
#        'Debt Consolidation Loan', 'Mortgage Loan', 'Student Loan',
#        'Payday Loan', 'Auto Loan', 'Home Equity Loan'],
#       dtype='object')

# %%
df1['Credit_Score']
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 9995    2
# 9996    1
# 9997    1
# 9998    2
# 9999    1
# Name: Credit_Score, Length: 10000, dtype: int64

# %%
for col in df1:
    print(col,df1[col].unique())
# Out:
# Month ['April' 'January' 'June' 'May' 'August' 'March' 'July' 'February']
# Age [38. 46. 20. 15. 55. 40. 25. 24. 39. 34. 49. 54. 43. 36. 32. 42. 31. 47.
#  21. 35. 22. 51. 19. 26. 33. 16. 18. 30. 27. 44. 48. 53. 50. 41. 37. 52.
#  23. 28. 29. 14. 45. 17. 56.]
# Occupation ['Lawyer' 'Doctor' 'Accountant' 'Scientist' 'Mechanic' 'Journalist'
#  'Writer' 'Teacher' 'Developer' 'Musician' 'Media_Manager' 'Architect'
#  'Engineer' 'Manager' 'Entrepreneur']
# Annual_Income [ 18040.67  126091.71   80436.12  ...  71933.7   122434.23   11032.075]
# Monthly_Inhand_Salary [ 1270.38916667 10406.6425      6643.01       ...  1583.11666667
#  10004.8525       790.33958333]
# Num_Bank_Accounts [ 5.  1.  3.  9. 10.  4.  7.  8.  0.  6.  2. 11.]
# Num_Credit_Card [ 5.  4.  7.  6.  9.  3. 10.  2.  1.  8. 11.]
# Interest_Rate [27.  6. 13. 14. 11. 32.  5. 10. 15. 12.  8.  3. 16.  4. 29. 33.  9. 20.
#   2.  7. 25. 18. 19. 21.  1. 17. 23. 22. 31. 30. 28. 26. 34. 24.]
# ...

# %% [markdown]
# pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_columns', None)

# %%
df1.describe()
# Out:
#                 Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  10000.000000   10000.000000           10000.000000        10000.00000
# mean      33.287800   48376.707884            4028.559583            5.40130
# std       10.610119   35179.938693            2947.101427            2.58904
# min       14.000000    7005.930000             303.645417            0.00000
# 25%       25.000000   19243.000000            1612.983125            4.00000
# 50%       33.000000   37756.850000            3097.162292            6.00000
# 75%       41.000000   68985.800000            5820.826974            7.00000
# max       56.000000  154242.480000           12642.970000           11.00000
#
#        Num_Credit_Card  Interest_Rate   Num_of_Loan  Delay_from_due_date  \
# count     10000.000000   10000.000000  10000.000000         10000.000000
# mean          5.528700      14.582600      3.520900            19.537900
# ...

# %%
for col in df1:
    print(col,df1[col])

# %%
df1['Annual_Income'].unique()
# Out:
# array([ 18040.67 , 126091.71 ,  80436.12 , ...,  71933.7  , 122434.23 ,
#         11032.075])

# %%
df = pd.read_csv('datasets/Credit Score/train.csv')
# Out:
# C:\Users\djibr\AppData\Local\Temp\ipykernel_6664\3712749863.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('datasets/Credit Score/train.csv')

# %%
df['Month'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August'], dtype=object)

# %%
df1['Occupation'].unique()
# Out:
# array(['Lawyer', 'Doctor', 'Accountant', 'Scientist', 'Mechanic',
#        'Journalist', 'Writer', 'Teacher', 'Developer', 'Musician',
#        'Media_Manager', 'Architect', 'Engineer', 'Manager',
#        'Entrepreneur'], dtype=object)

# %%
df1.describe()
# Out:
#                 Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  10000.000000   10000.000000           10000.000000        10000.00000
# mean      33.287800   48376.707884            4028.559583            5.40130
# std       10.610119   35179.938693            2947.101427            2.58904
# min       14.000000    7005.930000             303.645417            0.00000
# 25%       25.000000   19243.000000            1612.983125            4.00000
# 50%       33.000000   37756.850000            3097.162292            6.00000
# 75%       41.000000   68985.800000            5820.826974            7.00000
# max       56.000000  154242.480000           12642.970000           11.00000
#
#        Num_Credit_Card  Interest_Rate   Num_of_Loan  Delay_from_due_date  \
# count     10000.000000   10000.000000  10000.000000         10000.000000
# mean          5.528700      14.582600      3.520900            19.537900
# ...

# %%
df1['Payment_Behaviour'].unique()
# Out:
# array(['Low_spent_Small_value_payments',
#        'High_spent_Small_value_payments',
#        'Low_spent_Large_value_payments',
#        'Low_spent_Medium_value_payments',
#        'High_spent_Medium_value_payments',
#        'High_spent_Large_value_payments'], dtype=object)

# %%
df1.columns
# Out:
# Index(['Month', 'Age', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score', 'Personal Loan', 'Credit-Builder Loan',
#        'Debt Consolidation Loan', 'Mortgage Loan', 'Student Loan',
#        'Payday Loan', 'Auto Loan', 'Home Equity Loan'],
#       dtype='object')

# %%
df['Personal Loan'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
df1["Personal_Loan"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 4772 to 9476
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     10000 non-null  object
#  1   Age                       10000 non-null  float64
#  2   Occupation                10000 non-null  object
#  3   Annual_Income             10000 non-null  float64
#  4   Monthly_Inhand_Salary     10000 non-null  float64
#  5   Num_Bank_Accounts         10000 non-null  float64
#  6   Num_Credit_Card           10000 non-null  float64
#  7   Interest_Rate             10000 non-null  float64
#  8   Num_of_Loan               10000 non-null  float64
#  9   Delay_from_due_date       10000 non-null  float64
#  10  Num_of_Delayed_Payment    10000 non-null  float64
#  11  Changed_Credit_Limit      10000 non-null  float64
#  12  Num_Credit_Inquiries      10000 non-null  float64
# ...

# %%
df.head(1)
# Out:
#      Month   Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 4772   May  22.0  Journalist       14070.22            1148.518333
#
#       Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 4772                9.0              9.0           24.0          6.0
#
#       Delay_from_due_date  ...  Monthly_Balance  Credit_Score  Personal Loan  \
# 4772                 40.0  ...       279.704819             0            0.0
#
#       Credit-Builder Loan  Debt Consolidation Loan  Mortgage Loan  \
# 4772                  1.0                      0.0            1.0
#
#       Student Loan Payday Loan  Auto Loan  Home Equity Loan
# 4772           0.0         1.0        1.0               1.0
#
# [1 rows x 31 columns]

# %%
print(df.head(1))
# Out:
#      Month   Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 4772   May  22.0  Journalist       14070.22            1148.518333
#
#       Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 4772                9.0              9.0           24.0          6.0
#
#       Delay_from_due_date  ...  Monthly_Balance  Credit_Score  Personal Loan  \
# 4772                 40.0  ...       279.704819             0            0.0
#
#       Credit-Builder Loan  Debt Consolidation Loan  Mortgage Loan  \
# 4772                  1.0                      0.0            1.0
#
#       Student Loan Payday Loan  Auto Loan  Home Equity Loan
# 4772           0.0         1.0        1.0               1.0
#
# [1 rows x 31 columns]

# %%
df.describe()
# Out:
#                 Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  10000.000000   10000.000000           10000.000000        10000.00000
# mean      33.287800   48376.707884            4028.559583            5.40130
# std       10.610119   35179.938693            2947.101427            2.58904
# min       14.000000    7005.930000             303.645417            0.00000
# 25%       25.000000   19243.000000            1612.983125            4.00000
# 50%       33.000000   37756.850000            3097.162292            6.00000
# 75%       41.000000   68985.800000            5820.826974            7.00000
# max       56.000000  154242.480000           12642.970000           11.00000
#
#        Num_Credit_Card  Interest_Rate   Num_of_Loan  Delay_from_due_date  \
# count     10000.000000   10000.000000  10000.000000         10000.000000
# mean          5.528700      14.582600      3.520900            19.537900
# ...

# %%
df['Month']
# Out:
# 4772       May
# 2764    August
# 2973       May
# 3018     March
# 4581     March
#          ...
# 469        May
# 4807      June
# 5839     April
# 6730      June
# 9476       May
# Name: Month, Length: 10000, dtype: object

# %%
df['Occupation'].unique()
# Out:
# array(['Journalist', 'Musician', 'Architect', 'Mechanic', 'Writer',
#        'Manager', 'Scientist', 'Engineer', 'Lawyer', 'Media_Manager',
#        'Accountant', 'Doctor', 'Teacher', 'Entrepreneur', 'Developer'],
#       dtype=object)
